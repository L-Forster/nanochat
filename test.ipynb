# %%
# !python scripts.base_train -- --tokenizer_name=hansard --data_dir=/home/louis/nanochat/data/hansard_data
# Out:
# python3: can't open file '/content/scripts.base_train': [Errno 2] No such file or directory
